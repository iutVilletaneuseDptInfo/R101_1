# %% [markdown]
# # Problème 2 : Le jeu du pendu
#
# Cet exercice consiste à code le [jeu du pendu](https://fr.wikipedia.org/wiki/Pendu_(jeu)). Bien sûr, nous ne coderons pas la partie graphique (dessin du pendu).
#
# Cet exercice est formé d'une suite de questions permettant d'aborder les notions de bases de programmation suivantes :
# - fonctions (*chapitres 4 et 5*)
# - tirer un entier aléatoire (*Chapitre 6*)
# - Parcours de chaîne (*chapitre 7*)
# - lecture d'un fichier (*chapitre 8*)
#
# Nous utiliserons la biliothèque random pour tirer aléatoirement des nombres entiers.

# %%
import random

# %% [markdown]
# ## Partie 1 : Fonctions utiles
#
# Dans cette partie, on définit quelques fonctions qui seront utiles par la suite pour programmer le jeu.
#
# ### Question 1 : Saisie contrôlée
#
# On souhaite que l'utilisateur saisisse à chaque tour une seule lettre.
# Cette lettre devra être non accentuée.
#
# Définir une fonction `estLettreSansAccent` qui prend en paramètre une châine de caractères et retourne `True` si cette chaîne correspond à *une seule lettre non accentuée*.
#
# **Remarque :** On pourra utiliser les fonctions [`isalpha`](https://www.w3schools.com/python/ref_string_isalpha.asp) et [`isascii`](https://www.w3schools.com/python/ref_string_isascii.asp) de la bibliothèque `str`. Une chaîne de caractères est composée uniquement de lettres sans accent si ces deux fonctions retournent `True` pour cette chaîne.
#
# Exemple d'utilisation des fonctions `isalpha` et `isascii` :
# ```python
# s = "étudiant"
# if s.isalpha():
#     print(s, "ne contient que des lettres")
#
# s = "c'est un etudiant"
# if s.isascii():
#     print(s, "ne contient que des caractères ascii")
# ```

# %% [markdown]
# **Remarque :** Plutôt que d'utiliser les fonctions `isalpha` et `isascii`, on peut tester si le caractère est une minuscule (compris entre `"a"` et `"z"`) ou une majuscule (compris entre `"A"` et `"Z"`)

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# Définir ensuite la fonction `saisie` demandant à l'utilisateur de saisir une lettre sans accent. La saisie sera répétée jusqu'à ce que l'utilisateur saisisse une valeur correcte. La valeur retournée par la fonction sera la lettre saisie par l'utilisateur en majuscule.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 2 : Initialisation du mot à trouver
#
# Définir une fonction `initialise` prenant en paramètre une chaîne de caractères `s` et retournant une autre chaîne contenant `len(s)` fois le symbole `"_"`.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 3 : mise à jour du mot à trouver
#
# Dans ce jeu, à chaque que le joueur trouve une lettre du mot, les symboles `_` correspondant à cette lettre sont mis à jour.
#
# Définir la fonction `maj_mot` prenant en paramètre :
# - la chaîne `mot` correspondant au mot à trouver où les lettres qui n'ont pas encore été trouvées par le joueur sont remplacées par des underscores,
# - la chaîne `motATrouve` correspondant au mot à trouver,
# - le caractère `lettre` correspondant à la lettre donnée par le joueur
#
# La fonction doit retourner une châine de caractères correspondant à `mot` mais où les underscores correspondant à `lettre` dans `motATrouve` sont remplacées par la lettre.
#
# Voici la fonction de tests unitaires que la fonction `maj_mot` doit vérifier.

# %%
def test_maj_mot():
    assert maj_mot("____", "abcd", "a") == "a___"
    assert maj_mot("b_____r", "bonjour", "o") == "bo__o_r"
    assert maj_mot("b_____r", "bonjour", "z") == "b_____r"
    assert maj_mot("b_____r", "bonjour", "b") == "b_____r"
    assert maj_mot("b_____r", "bonjour", "n") == "b_n___r"
    print("Test de la fonction maj_mot : ok")

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ## Partie 2 : jeu du pendu avec un mot fixé (passé en paramètre)
#
# ### Question 1 : Fonction `gagne`
#
# Définir la fonction `gagne` prenant en paramètre le mot courant, le mot à trouver et le nombre de tentatives restantes et retournant :
# -  1 si la partie est gagnée
# - -1 si la partie est perdue
# - 0 sinon

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 2 : Fonction `partie`
#
# Définir la fonction `partie` prenant en paramètre un mot à trouver et permettant à l'utilisateur de jouer une partie du jeu du pendu avec ce mot.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ## Partie 3 : jeu du pendu avec un mot choisi aléatoirement

# %% [markdown]
# On souhaite maintenant pour jouer avec des mots choisis aléatoirement.
# Pour cela, on suppose que l'on a un fichier contenant un mot par ligne.
#
# Définir `motAleatoire` prenant en paramètre un fichier de mot et retournant un mot aléatoire de ce fichier.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# Donner le code permettant de jouer au jeu du pendu avec un mot aléatoire du fichier `liste_mots_pendu.txt` qui se trouve dans le même répertoire que ce notebook.

# %%
############################## 
#   Saisir votre code ici.   #
##############################
