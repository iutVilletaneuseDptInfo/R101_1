# %% [markdown]
# # Problème 3 : date et heure
#
# Ce problème consiste à définir un ensemble de fonctions pour traiter la date et l'heure dans des programmes.
#
# **Remarque :** Les 5 premiers exercices doivent être faits. Les exercices suivants sont plus difficiles et sont optionnels.
#
# **Notions abordées :** fonctions avec valeurs de retour, tableaux

# %% [markdown]
# ## Exercice 1 : Heure valide*
#
# ### Question 1
#
# Définir la fonction `estHeureValide` prenant en paramètre une heure (donnée par 3 entiers : le nombre d'heures, le nombre de minutes et le nombre de secondes) et retournant `True` si l'heure est valide, et `False` sinon.
#
# **Remarque :** Une heure est considérée comme valide si le nombre d'heures et compris entre 0 et 23 et le nombre de minutes et secondes sont compris entre 0 et 59.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 2
#
# On souhaite maintenant représenter une heure par un tableau de 3 entiers. La valeur de la première case correspond aux heures, la deuxième aux minutes et la troisième aux secondes. Par exemple, 11 heures, 22 minutes et 33 secondes sera représentée par le tableau `[11, 22, 33]`.
#
# Définir de nouveau `estHeureValide` prenant une heure en paramètre sous forme d'un tableau et retournant `True` si cette heure est valide et `False` sinon.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 3
#
# Définir une fonction de tests unitaires pour la fonction `estHeureValide`.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ## Exercice 2 : Nombre de secondes depuis minuit*

# %% [markdown]
# ### Question 1
#
# Définir la fonction `nbs` qui étant donné une heure passée en paramètre sous forme de tableau, retourne le nombre de secondes passées depuis minuit si l'heure passée en paramètre est valide et -1 sinon. À titre d'exemple, `nbs(1,1,1)` doit retourner 3661 car une heure contient 3600 secondes et une minute 60 secondes.
#
# **Remarque :** Pour tester si l'heure passée en paramètre est valide, vous utiliserez la fonction `estHeureValide` de l'exercice précédent.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 2
#
# Définir une fonction `test_nbs` qui correspond au test unitaire de la fonction `nbs`. Vérifier que la fonction de la Question 1 satisfait tous les tests.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ## Exercice 4 : Année bissextile*

# %% [markdown]
# ### Question 1
#
# Définir la fonction `estBissextile` qui retourne `True` si l'année passée en paramètre correspond à une année bissextile, et `False` sinon.
#
# **Remarque :** Une année est bissextile si
# * elle est divisible par 4
# * mais n'est pas divible par 100
# * sauf si elle est divisible par 400
#
# Ainsi 2008 était bissextile, 1900 n'était pas bissextile et 2000 était bissextile.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 2
#
# Vérifier que la fonction `estBissextile` définie à la Question 1 satisfait les tests unitaires suivants.

# %%
def test_estBissextile():
    assert estBissextile(2008)
    assert estBissextile(2000)
    assert not estBissextile(1002)
    assert not estBissextile(1900)
    print("Test de la fonction estBissextile : ok")


test_estBissextile()

# %% [markdown]
# ## Exercice 4 : Nombre de jours dans un mois**

# %% [markdown]
# ### Question 1
#
# Définir la fonction `nbjours` prenant en paramètre un numéro de mois (entre 1 et 12), ainsi qu'une année et retournant le nombre de jours dans le mois.
#
# **Rappel :**
# * Janvier, mars, mai, juillet, août, octobre et décembre contiennent 31 jours.
# * Février contient 29 jours pour les années bissextiles et 28 jours sinon.
# * Avril, juin, septembre et novembre contiennent 30 jours.
#
# **Remarques :**
# * La fonction retournera -1 si le mois n'est pas valide.
# * On utilisera la fonction `estBissextile` pour déterminer si l'année passée en paramètre est bissextile.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# #### Question 2
#
# Vérifier que la fonction `nbjours` définie à la Question 1 satisfait les tests unitaires suivants.

# %%
def test_nbjours():
    assert nbjours(1,1900) == 31
    assert nbjours(2,1900) == 28
    assert nbjours(2,2000) == 29
    assert nbjours(3,1900) == 31
    assert nbjours(4,1900) == 30
    assert nbjours(5,1900) == 31
    assert nbjours(6,1900) == 30
    assert nbjours(1,1900) == 31
    assert nbjours(1,1900) == 31
    assert nbjours(9,1900) == 30
    assert nbjours(10,1900) == 31
    assert nbjours(11,1900) == 30
    assert nbjours(12,1900) == 31
    print("test de la fonction nbjours : ok")
test_nbjours()

# %% [markdown]
# ## Exercice 5 : Date valide*
#
# ### Question 1
#
# On définit une date à l'aide d'un tableau de 3 cases : la première contient le jour, la deuxième contient le mois et la troisième contient l'année. Par exemple, le premier février 2024 est représenté par `[1, 2, 2024]`.
#
# Définir la fonction `estDateValide` prenant en paramètre une date et retournant `True` si la date est valide, et `False` sinon.
#
# **Remarque :** on utilisera la fonction `nbjours` de l'exercice précédent pour vérifier si le jour passé en paramètre est correct.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# #### Question 2
#
# Vérifier que la fonction définie à la Question 1 satisfait les tests unitaires suivants.

# %%
def test_estDateValide():
    assert estDateValide([1,1,1970])
    assert estDateValide([1,1,-1])
    assert estDateValide([1,1,0])
    assert estDateValide([31,1,1970])
    assert estDateValide([28,2,1970])
    assert estDateValide([29,2,2000])
    assert not estDateValide([29,2,2001])
    assert not estDateValide([-1,1,2000])
    assert estDateValide([31,12,2000])
    assert not estDateValide([31,11,2000])
    assert not estDateValide([1970])
    print("Test de la fonction estDateValide : ok")

test_estDateValide()

# %% [markdown]
# ## Exercice 6 : Construire une heure à partir d'une chaîne de caractères**
#
# ### Question 1
#
# Définir la fonction `str2hour` prenant en paramètre une chaîne de caractères représentant une heure au format `"hh:mm:ss"` et retournant un tableau de 3 entiers contenant les heures, minutes et secondes. Par exemple, l'appel de la fonction avec `01:02:03` doit renvoyer le tableau `[1, 2, 3]`.
#
# **Attention :** si la chaîne ne respecte pas le bon format (deux chiffres, ":", deux chiffres, ":" et deux chiffres) ou si elle ne correspond pas à une heure valide, la fonction doit retourner `[0, 0, 0]`.
#
# **Aide :** On utilisera la fonction `split` s'appliquant à une chaîne. Cette fonction permet de découper une chaîne en morceaux en coupant à chaque fois que le séparateur (chaîne de caractères donné en argument) est rencontré. Par exemple si `s = "01:02:03"`, alors `s.split(":")` retournera le tableau `["01", "02", "03"]`.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 2
#
# Vérifiez que votre fonction vérifie les tests unitaires suivants.

# %%
def test_str2hour():
    assert str2hour("01:2:03") == [0, 0, 0]
    assert str2hour("01:02:03") == [1, 2, 3]
    assert str2hour("11:22:59") == [11, 22, 59]
    assert str2hour("A1:02:03") == [0, 0, 0]
    assert str2hour("31:02:03") == [0, 0, 0]

test_str2hour()

# %% [markdown]
# ## Exercice 7 : Construire une date à partir d'une chaîne de caractères**
#
# ### Question 1
#
# Définir la fonction `str2date` prenant en paramètre une chaîne de caractères et retournant la date associée sous forme de tableau.
# Si la date n'est pas valide, la date retournée est le 1er janvier 1970.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 2
#
# Vérifiez que votre fonction vérifie les tests unitaires suivants.

# %%
def test_str2date():
    assert str2date("1/1/1970") == [1, 1, 1970]
    assert str2date("29/2/2004") == [29, 2, 2004]
    assert str2date("29/2/2003") == [1, 1, 1970]
    assert str2date("1970") == [1, 1, 1970]
    assert str2date("1:1:1970") == [1, 1, 1970]
    print("Test de la fonction str2date : ok")

test_str2date()

# %% [markdown]
# ## Exercice 8 : date en toutes lettres**
#
# ### Question 1
#
# Définir la fonction `expandDate` prenant en paramètre une date sous forme de tableau et retournant une chaîne de caractères vérifiant les conditions suivantes :
# - le mois est écrit en toutes lettres
# - Si le jour est le premier jour du mois, la chaîne doit contenir `"1er"`
#
# Si la date passée en paramètre, la chaîne retournée est `"invalide"`.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 2
#
# Vérifiez que votre fonction vérifie les tests unitaires suivants.

# %%
def test_expandDate():
    assert expandDate([1, 1, 1970]) == "1er janvier 1970"
    assert expandDate([2, 1, 1970]) == "2 janvier 1970"
    assert expandDate([10, 10, 2010]) == "10 octobre 2010"
    assert expandDate([30, 2, 1970]) == "invalide"
    print("Test de la fonction expandDate : ok")

test_expandDate()

# %% [markdown]
# ## Exercice 9 : Nombre de jours depuis le 1er janvier 1970***

# %% [markdown]
# ### Question 1
#
# Définir la fonction `jours1970` qui prend en paramètre une date et retourne le nombre de jours passés depuis le 1er janvier 1970. Si la date passée en paramètre n'est pas valide, la fonction retourne -1. Si la date est avant le 1er janvier 1970, alors la fonction renvoie un nombre négatif dont la valeur absolue est le nombre de jours depuis la date jusqu'au 01/01/1970.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 2
#
# Vérifier que la fonction définie à la Question 1 satisfait les tests unitaires suivants.

# %%
def test_jours1970():
    assert jours1970([1, 1, 1970]) == 0
    assert jours1970([2, 1, 1970]) == 1
    assert jours1970([1, 2, 1970]) == 31
    assert jours1970([1, 1, 1971]) == 365
    assert jours1970([1, 1, 1975]) == 365 * 5 + 1
    assert jours1970([31, 12, 1969]) == -1
    assert jours1970([1, 12, 1969]) == -31
    assert jours1970([31, 12, 1968]) == -366
    print("Test de la fonction jours1970 : ok")


test_jours1970()

# %% [markdown]
# ### Exercice 10 : Timestamp*
#
# En informatique, pour comparer des dates, on utilise le *timestamp*. Un timestamp correspond au temps écoulé depuis un événement précis (qui sert alors de référence). Sur les systèmes UNIX, le timestamp correspond au nombre de secondes écoulées depuis le 1er janvier 1970 à minuit.
#
# #### Question 1
#
# Définir la fonction `timestamp` qui prend en paramètre une date et une heure, et retourne le nombre de secondes écoulées par rapport au 1er janvier 1970 si la date est valide et -1 sinon.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 2 :
#
# Vérifier que la fonction définie à la Question 1 satisfait les tests unitaires suivants.

# %%
def test_timestamp():
    assert timestamp([1, 1, 1970], [0, 0, 0]) == 0
    assert timestamp([1, 1, 2019], [12, 0, 0]) == 1546344000
    assert timestamp([1, 1, 1969], [0, 0, 0]) == -31536000
    assert timestamp([1, 1, 1949], [0, 0, 0]) == -662688000
    assert timestamp([1, 1, 1948], [0, 0, 0]) == -694310400
    assert timestamp([2, 1, 1948], [0, 0, 0]) == -694224000
    assert timestamp([1, 6, 1948], [0, 0, 0]) == -681177600
    assert timestamp([10, 12, 1948], [0, 0, 0]) == -664588800
    assert timestamp([10, 12, 1948], [14, 10, 20]) == -664537780
    print("Test de la fonction timestamp : ok")


test_timestamp()
