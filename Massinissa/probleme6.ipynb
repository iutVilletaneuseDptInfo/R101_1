# %% [markdown]
# # Problème 6 : Championnat de football

# %% [markdown]
# Le but de ce problème est de simuler une poule de football et de déterminer le gagnant.
# Un fichier d'équipes est un fichier texte contenant une équipe par ligne. Le fichier `equipes.txt` est un exemple de fichier d'équipes.
#
# ## Question 1
#
# Définir la fonction `equipesAleatoires` prenant en paramètre un entier `n` et un nom de fichier d'équipes et retournant un tableau de `n` équipes choisies aléatoirement dans le fichier.
# Si le nombre `n` est négatif ou s'il est plus grand que le nombre d'équipes dans le fichier, la fonction retourne un tableau vide.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ## Question 2
#
# Définir la fonction `match` qui prend en paramètre deux équipes (chaînes de caractères), simule un match entre ces deux équipes et retourne une chaîne de caractères contenant le nom des équipes et le nombre de buts qu'elles sont marquées au format suivant :
# ```python
# "eq1 : nbButsEquipe1, eq2 : nbButsEquipe2"
# ```
# où `eq1` et `eq2` sont remplacées par les noms des deux équipes et `nbButsEquipe1` et `nbButsEquipe2` sont des nombres choisis aléatoirement entre 0 et 4 inclus. La valeur retournée par `match("Angleterre", "Pays-Bas")` pourraît être :
# ```python
# "Angleterre : 2, Pays-Bas : 1"
# ```

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ## Question 3
#
# Une poule en football consiste en un match entre toute paire d'équipes de la poule.
#
# Définir la fonction `poule` prenant en paramètre un tableau d'équipes et un nom de fichier et écrivrant dans ce fichier le résultats d'une poule entre ces équipes. Si la fonction est appelée avec le tableau `["Italie", "Croatie", "Espagne"]`, alors le fichier généré pourrait être :
# ```
# Italie : 3, Croatie : 3
# Italie : 2, Espagne : 0
# Croatie : 1, Espagne : 1
# ```

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ## Question 4
#
# Dans une poule, une équipe gagne 3 points par victoire, 1 point par match nul et 0 point pour une défaite.
#
# Définir la fonction `calculPoints` qui prend en paramètre un nom de fichier de poule (du format de celui généré par la question précédente) et retourne un dictionnaire où les clés sont les noms des équipes de la poule et les valeurs leur nombre de points à l'issue de la poule.
#
# Par exemple, si cette fonction est appelée avec le fichier donné en exemple à la question précédente, elle doit retourner le dictionnaire :
# ```python
# {
#     "Italie" : 4,
#     "Croatie" : 2,
#     "Espagne" : 1
# }
# ```

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ## Question 5
#
# Le gagnant d'une poule est l'équipe qui a le plus de points. En cas d'égalité, le gagnant est choisi aléatoirement parmi les équipes qui ont le plus de points.
#
# Définir la fonction `gagnantPoule` prenant en paramètre un dictionnaire d'équipes avec leur points (comme celui retourné par la fonction précédente) et détermine le gagnant.

# %%
############################## 
#   Saisir votre code ici.   #
##############################
