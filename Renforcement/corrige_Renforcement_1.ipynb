# %% [markdown]
# # <center> Exercices de révision - Corrigé </center> #

# %% [markdown]
# ## Les alternatives ##

# %% [markdown]
# ### Exercice : Affichage alternatif de `oui` ###
# - Pour quelles valeurs de `x` s'affiche `oui` dans les
# cas suivants ?

# %%
if (x > 100):
    print("non")
else :
    print("oui")

# %% [markdown]
# si `x <= 100`

# %%
if (x > 100):
    print("non")
elif (x > 90):
    print("oui")

# %% [markdown]
# 90<x<=100

# %%
if (not(x > 0 and a < 100)):
    print("non")
elif (x > 70):
    print("oui")

# %% [markdown]
# si `70 < x < 100`

# %% [markdown]
# *Pour vous entraîner seul*
#
# - Pour quelles valeurs de `x` s'affiche `oui` dans les
# cas suivants ?

# %%
if (x > 13):
    print("non")
else:
    print("oui")

# %% [markdown]
# si `x <= 13`

# %%
if (x > 13):
    print("non")
if (x > 20):
    print("oui")

# %% [markdown]
# si `x > 20`

# %%
if (x > 13 and x < 20):
    print("non")
elif (x > 15):
    print("oui")

# %% [markdown]
# si `x >=20`

# %%
if (not(x > 13 and x < 20)):
    print("non")
elif (x > 15):
    print("oui")

# %% [markdown]
# si `15 < x < 20`

# %% [markdown]
# ### Exercice : Programmes mystère ###
# - Que fait le programme ci-dessous quand `A` vaut 1, 5 ou 7 ?

# %%
A=1
B = 10
if (A < 5) or (B < A):
             print ('oui')
elif (A < 7) and (B <= 2*A):
             print ("non")

# %% [markdown]
# - si `A=1`, il affiche `"oui"`
# - si `A=5`, il affiche `"non"`
# - si `A=7`, il n'affiche rien

# %% [markdown]
# *Pour vous entrainer seuls*
#
# - Que fait le programme ci-dessous quand `a`vaut 1, 4 ou 15 ?

# %%
b =4
if (a<4) or (b!=4):
             print ('gagné')
elif (a==4) and (b==4):
             print ("presque gagné")

# %% [markdown]
# - Si a =1, le programme affiche "gagné"
# - Si a =4, le programme affiche "presque gagné"
# - Si a =15, le programme  n'affiche rien

# %% [markdown]
# ### Exercice : Comparaison de chaînes de caractères ###

# %% [markdown]
# Ecrire un programme qui permet de saisir deux chaînes de caractères et indique si la première chaîne  est supérieure, inférieure ou égale à la seconde chaine.

# %%
############## 
# Correction #
##############
print("saisir une chaine de caractère")
ch1=input()
print("saisir une autre chaine de caractère")
ch2=input() 
if ch1<ch2 :
    print (ch1, "<", ch2)
elif ch2<ch1:
    print(ch1,">", ch2)
else : 
    print(ch1,"est égale à", ch2)

# %% [markdown]
# ## Boucles ##

# %% [markdown]
# ### Exercice : Affichages ordonnés ###
# - Ecrire un programme qui affiche les entiers pairs de 100 à 0 (inclus)

# %%
i=100
while i>=0:
    print(i)
    i-=2

# %% [markdown]
# - Ecrire un programme qui affiche les entiers multiples de 10 de 100 à 300 (inclus)

# %%
i=100
while i<=300:
    print(i)
    i+=10

# %% [markdown]
# ### Exercice : Saisie contrôlée ###
# - Ecrire un programme qui demande à l'utilisateur un entier `n` jusqu'à ce que cet entier soit strictement supérieur à 1000 et affiche la valeur saisie à la fin.

# %%
n=int(input("Donner un entier strictement supérieur à 1000\n"))
while n<=1000:   # not(n>1000)est une condition équivalente   
    n=int(input("Donner un entier strictement supérieur à 1000\n"))

print("la valeur saisie est",n)

# %% [markdown]
# - Ecrire un programme qui demande à l'utilisateur un flottant `f` jusqu'à ce que ce flottant soit strictement compris entre 5 et 10 (`5 < f < 10`) et affiche la valeur saisie à la fin.

# %%
f=float(input("Donner un flottant entre 5 et 10 \n"))
while not(5<f and f<10):   # f<=5 or f>=10 est équivalent
    f=float(input("Donner un entier entre 5 et 10\n"))

print("la valeur saisie est",f)

# %% [markdown]
# - Ecrire un programme qui demande à l'utilisateur un caractère `c` jusqu'à ce que ce caractère soit une lettre minuscule et affiche la valeur saisie à la fin.

# %%
c=input("Donner une lettre minuscule\n")
while 'a'>c or c>'z': # not('a'<=c and c<='z')
    c=input("Donner une lettre minuscule \n")

print("la valeur saisie est",c)

# %% [markdown]
# ### Exercice : Programmes mystère ###
# - Qu'affiche ce programme ? Qu'affiche-t-il si on remplace la première ligne par `i = 7` ?

# %% [markdown]
# **Correction**
# - Si A =1, le programme affiche oui
# - Si A =5, le programme affiche non
# - Si A =7, le programme n'affiche rien

# %%
i = 5
while i%9 != 0:
    print(i)
    i += 10
print(i)

# %% [markdown]
# - Que valent `a` et `b` à la fin du programme suivant ?

# %%
a = 1
b = 0
while a < 30 or b%5 == 0:
    a *= 2
    b += 7
